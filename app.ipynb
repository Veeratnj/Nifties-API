# %%
import pandas as pd

# %%
df=pd.read_csv('OpenAPIScripMaster.csv')
# Out:
# /tmp/ipykernel_130260/2437617722.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('OpenAPIScripMaster.csv')

# %%
df[df['token'] == 49774]['symbol']
# Out:
# 56572    NIFTY03FEB2624800CE
# Name: symbol, dtype: object
